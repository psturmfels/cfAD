# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from GetJSON import *

# %%
base_processed = get('folders.processed')
base_processed
# Out:
# '/projects/leelab2/data/AD_DATA/processed/PCG_unaltered/'

# %%
ACT_file = base_processed + 'ACT.tsv'
ACT_df   = pd.read_csv(ACT_file, sep='\t', header=0)
ACT_df.head()
# Out:
#        PCG  488395315  496100277  496100278  496100279  496100281  496100283  \
# 0   MT-ND1        NaN        NaN        NaN        NaN        NaN        NaN
# 1   MT-ND2        NaN        NaN        NaN        NaN        NaN        NaN
# 2   MT-CO1        NaN        NaN        NaN        NaN        NaN        NaN
# 3   MT-CO2        NaN        NaN        NaN        NaN        NaN        NaN
# 4  MT-ATP8        NaN        NaN        NaN        NaN        NaN        NaN
#
#    496100284  496100285  496100287    ...      496100661  496100663  \
# 0        NaN        NaN        NaN    ...            NaN        NaN
# 1        NaN        NaN        NaN    ...            NaN        NaN
# 2        NaN        NaN        NaN    ...            NaN        NaN
# 3        NaN        NaN        NaN    ...            NaN        NaN
# 4        NaN        NaN        NaN    ...            NaN        NaN
#
#    496100664  496100665  496100666  496100667  496100669  496100670  \
# ...

# %%
WM_file = base_processed + 'WM.tsv'
WM_df   = pd.read_csv(WM_file, sep='\t', header=0)
joined = ACT_df.merge(WM_df, on='PCG')
joined[30:35]
# Out:
#         PCG  488395315  496100277  496100278  496100279  496100281  496100283  \
# 30  C2orf88   7.726540  17.770345  16.768485   7.141040   9.736386   5.545339
# 31  DEFB125   0.000000   0.000000   0.000000   0.000000   0.000000   0.000000
# 32    TRAF6   7.700510   8.030912   9.513670   8.146404   5.796468   7.024364
# 33    ASIC2   4.536997   0.391727   0.682329   6.288810   3.423196   5.351477
# 34   LRRC41  10.663472  11.393003  11.020903  12.635883  14.100137  12.467638
#
#     496100284  496100285  496100287    ...      WGACON-190  WGAAD-76  \
# 30   8.041198   6.336481   6.536888    ...             NaN       NaN
# 31   0.000000   0.000000   0.000000    ...             NaN       NaN
# 32   6.453870   7.290461   6.601456    ...             NaN       NaN
# 33   4.977449   4.967196   4.939919    ...             NaN       NaN
# 34  12.655126  13.058410  10.868391    ...           317.3     313.2
#
#     WGACON-191  WGAAD-69  WGAAD-45  WGAAD-89  WGAAD-391  WGACON-67  WGAAD-386  \
# ...

# %%
ACT_pheno = pd.read_csv(get('folders.phenotypes') + 'ACT.tsv', sep='\t', header=0)
ACT_pheno = ACT_pheno.set_index('sample_name').T.rename_axis('PCG').rename_axis(None, 1).reset_index()
ACT_pheno
# Out:
#            PCG  488395315  496100277  496100278  496100279  496100281  \
# 0        anyad   0.000000   0.000000   0.000000   0.000000   1.000000
# 1        cerad   3.000000   1.000000   0.000000   0.000000   0.000000
# 2        braak   3.000000   3.000000   6.000000   6.000000   1.000000
# 3    niareagan   2.000000   1.000000   2.000000   2.000000   1.000000
# 4          abf   0.765048   0.390684   0.001905   0.001905   0.065692
# 5         tauf   0.049372   0.160271   0.028088   0.028088   0.010962
# 6          abt   1.397207   1.040000   0.119041   0.119041   0.033981
# 7         taut   0.122597   0.134237   0.037288   0.037288   0.160703
# 8          abp   1.445710   0.307360   0.058797   0.058797   0.092416
# 9         taup   0.227024   0.095789   0.035579   0.035579   0.069414
# 10   abeta_ftp   0.771000   0.205000  -0.236000  -0.236000  -0.236000
# 11  phftau_ftp   0.019000  -0.007000  -0.038000  -0.038000  -0.022000
#
# ...

# %%
ACT_total_df = pd.concat([ACT_df, ACT_pheno], ignore_index=True, sort=False)
ACT_total_df
# Out:
#               PCG  488395315   496100277  496100278  496100279  496100281  \
# 0          MT-ND1        NaN         NaN        NaN        NaN        NaN
# 1          MT-ND2        NaN         NaN        NaN        NaN        NaN
# 2          MT-CO1        NaN         NaN        NaN        NaN        NaN
# 3          MT-CO2        NaN         NaN        NaN        NaN        NaN
# 4         MT-ATP8        NaN         NaN        NaN        NaN        NaN
# 5         MT-ATP6        NaN         NaN        NaN        NaN        NaN
# 6          MT-CO3        NaN         NaN        NaN        NaN        NaN
# 7          MT-ND3        NaN         NaN        NaN        NaN        NaN
# 8         MT-ND4L        NaN         NaN        NaN        NaN        NaN
# 9          MT-ND4        NaN         NaN        NaN        NaN        NaN
# 10         MT-ND5        NaN         NaN        NaN        NaN        NaN
# 11         MT-ND6        NaN         NaN        NaN        NaN        NaN
# ...
